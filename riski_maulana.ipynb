# %% [markdown]
# <a href="https://colab.research.google.com/github/Risuki1999/riski_maulana/blob/main/riski_maulana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset=pd.read_csv("/content/drive/My Drive/machine learning/pangan_19_20 (1).csv")
dataset
# Out:
#           Date  Beras  ...  Gula Pasir Kualitas Premium (kg)  Gula Pasir Lokal (kg)
# 0   02/09/2019  11700  ...                             14900                  12900
# 1   03/09/2019  11700  ...                             14900                  12900
# 2   04/09/2019  11700  ...                             14900                  12900
# 3   05/09/2019  11700  ...                             14900                  12850
# 4   06/09/2019  11700  ...                             14900                  12850
# ..         ...    ...  ...                               ...                    ...
# 92  13/01/2020  11800  ...                             14950                  13750
# 93  14/01/2020  11850  ...                             15000                  13800
# 94  15/01/2020  11850  ...                             14950                  13850
# 95  16/01/2020  11850  ...                             15000                  13900
# ...

# %%
dataset.head()
# Out:
#          Date  Beras  ...  Gula Pasir Kualitas Premium (kg)  Gula Pasir Lokal (kg)
# 0  02/09/2019  11700  ...                             14900                  12900
# 1  03/09/2019  11700  ...                             14900                  12900
# 2  04/09/2019  11700  ...                             14900                  12900
# 3  05/09/2019  11700  ...                             14900                  12850
# 4  06/09/2019  11700  ...                             14900                  12850
#
# [5 rows x 32 columns]

# %%
dataset.shape
# Out:
# (97, 32)

# %%
dataset.isnull().sum()
# Out:
# Date                                    0
# Beras                                   0
# Beras Kualitas Bawah I (kg)             0
# Beras Kualitas Bawah II (kg)            0
# Beras Kualitas Medium I (kg)            0
# Beras Kualitas Medium II (kg)           0
# Beras Kualitas Super I (kg)             0
# Beras Kualitas Super II (kg)            0
# Daging Ayam                             0
# Daging Ayam Ras Segar (kg)              0
# Daging Sapi                             0
# Daging Sapi Kualitas 1 (kg)             0
# Daging Sapi Kualitas 2 (kg)             0
# Telur Ayam                              0
# Telur Ayam Ras Segar (kg)               0
# Bawang Merah                            0
# Bawang Merah Ukuran Sedang (kg)         0
# Bawang Putih                            0
# Bawang Putih Ukuran Sedang (kg)         0
# Cabai Merah                             0
# Cabai Merah Besar (kg)                  0
# Cabai Merah Keriting  (kg)              0
# ...

# %%
dataset.max()
# Out:
# Date                                    31/12/2019
# Beras                                        11850
# Beras Kualitas Bawah I (kg)                  10900
# Beras Kualitas Bawah II (kg)                 10450
# Beras Kualitas Medium I (kg)                 11900
# Beras Kualitas Medium II (kg)                11750
# Beras Kualitas Super I (kg)                  13200
# Beras Kualitas Super II (kg)                 12700
# Daging Ayam                                  35200
# Daging Ayam Ras Segar (kg)                   35200
# Daging Sapi                                 118950
# Daging Sapi Kualitas 1 (kg)                 122550
# Daging Sapi Kualitas 2 (kg)                 113650
# Telur Ayam                                   26350
# Telur Ayam Ras Segar (kg)                    26350
# Bawang Merah                                 37600
# Bawang Merah Ukuran Sedang (kg)              37600
# Bawang Putih                                 35350
# ...

# %%
dataset.min()
# Out:
# Date                                    01/10/2019
# Beras                                        11700
# Beras Kualitas Bawah I (kg)                  10650
# Beras Kualitas Bawah II (kg)                 10250
# Beras Kualitas Medium I (kg)                 11700
# Beras Kualitas Medium II (kg)                11500
# Beras Kualitas Super I (kg)                  13000
# Beras Kualitas Super II (kg)                 12550
# Daging Ayam                                  30050
# Daging Ayam Ras Segar (kg)                   30050
# Daging Sapi                                 117200
# Daging Sapi Kualitas 1 (kg)                 120650
# Daging Sapi Kualitas 2 (kg)                 111900
# Telur Ayam                                   22900
# Telur Ayam Ras Segar (kg)                    22900
# Bawang Merah                                 22500
# Bawang Merah Ukuran Sedang (kg)              22500
# Bawang Putih                                 31000
# ...

# %%
dataset.describe()
# Out:
#               Beras  ...  Gula Pasir Lokal (kg)
# count     97.000000  ...              97.000000
# mean   11750.515464  ...           13060.309278
# std       37.842082  ...             231.045872
# min    11700.000000  ...           12850.000000
# 25%    11750.000000  ...           12900.000000
# 50%    11750.000000  ...           13050.000000
# 75%    11750.000000  ...           13100.000000
# max    11850.000000  ...           13900.000000
#
# [8 rows x 31 columns]

# %%
data=dataset.dropna()

# %%
data.shape
# Out:
# (97, 32)

# %%
dataset.dropna(axis=0, subset=['Daging Ayam','Beras'], inplace=True)

# %%
p=data['Bawang Merah']
p
# Out:
# 0     24850
# 1     24800
# 2     24550
# 3     24300
# 4     24250
#       ...
# 92    37250
# 93    37350
# 94    37300
# 95    37300
# 96    37400
# Name: Bawang Merah, Length: 97, dtype: int64

# %%
Fitur=['Date','Beras']
X=data[Fitur]
X
# Out:
#           Date  Beras
# 0   02/09/2019  11700
# 1   03/09/2019  11700
# 2   04/09/2019  11700
# 3   05/09/2019  11700
# 4   06/09/2019  11700
# ..         ...    ...
# 92  13/01/2020  11800
# 93  14/01/2020  11850
# 94  15/01/2020  11850
# 95  16/01/2020  11850
# 96  17/01/2020  11850
#
# [97 rows x 2 columns]
